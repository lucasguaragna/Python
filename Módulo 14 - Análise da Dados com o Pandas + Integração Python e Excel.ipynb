# %% [markdown]
# # O que é o Pandas e para que serve
#
# - Análise de Dados (seja para DataScience, seja para trabalhar de forma integrada com arquivos em Excel e Banco de Dados)
# - Melhor biblioteca/módulo para trabalhar com quantidades enormes de informações
# - Uma mistura de listas e dicionários de forma muito eficiente
#
# ## Resumo
#
# Se você trabalha com muitos dados, você vai precisar usar o pandas
#
# ## Forma de usar

# %%
import pandas as pd

# %% [markdown]
# ## Vamos aplicar e aprender mais no Projeto de DataScience

# %% [markdown]
# # Pandas e csv
#
# ## Resumo
#
# Quase sempre quando formos "ler" um arquivo csv, vamos usar o pandas. É prático e bem eficiente.
#
# ## Funcionamento

# %% [markdown]
# Forma mais básica: (muitas vezes não usaremos a forma mais básica)
# dataframe = pd.read_csv(arquivo_com_extensao)

# %% [markdown]
# - Vamos ler um arquivo real, com a Base de Dados de Vendas da Empresa "Contoso"

# %%
import pandas as pd
# precisamos passar o parâmetro ';'. O padrão é ','
vendas_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep = ';')
#print(vendas_df) # Fica feio, não visual
#print('-'*130)
#Se escrevermos:
vendas_df
# Out:
#                                       Nome do Produto  \
# 0               Contoso Wireless Laser Mouse E50 Grey
# 1       Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2      Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3      Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4     Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...                                               ...
# 1685        SV DVD 12-Inch Player Portable M400 Black
# 1686        SV DVD 9-Inch Player Portable M300 Silver
# 1687       SV DVD 12-Inch Player Portable M400 Silver
# 1688         SV DVD 9-Inch Player Portable M300 White
# 1689        SV DVD 12-Inch Player Portable M400 White
#
#                                    Descricao do Produto        Fabricante  \
# 0     Advanced 2.4 GHz cordless technology makes fre...      Contoso, Ltd
# 1                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# 2                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# ...

# %% [markdown]
# - Podemos passar o caminho do arquivo ao invés de precisar colocá-lo na pasta

# %%
vendas_df = pd.read_csv(r'C:\Users\lucas\OneDrive\Documentos\Cursos\Hashtag Treinamentos- Python Impressionador\Programas\Contoso - Cadastro Produtos.csv', sep = ';')
vendas_df
# Out:
#                                       Nome do Produto  \
# 0               Contoso Wireless Laser Mouse E50 Grey
# 1       Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2      Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3      Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4     Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...                                               ...
# 1685        SV DVD 12-Inch Player Portable M400 Black
# 1686        SV DVD 9-Inch Player Portable M300 Silver
# 1687       SV DVD 12-Inch Player Portable M400 Silver
# 1688         SV DVD 9-Inch Player Portable M300 White
# 1689        SV DVD 12-Inch Player Portable M400 White
#
#                                    Descricao do Produto        Fabricante  \
# 0     Advanced 2.4 GHz cordless technology makes fre...      Contoso, Ltd
# 1                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# 2                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# ...

# %% [markdown]
# # DataFrame
#
#
# ## Resumo
#
# É como se fosse uma tabela.
#
# - As colunas funcionam "como chaves de dicionário"
# - As linhas funcionam "como listas"
#
# ## Funcionamento

# %% [markdown]
# Temos um dataframe chamado vendas_df
#
# - vendas_df['coluna_x'] -> uma lista com os valores da coluna_x (em formato dataframe, é um dataframe com 1 coluna só)
# - vendas_df[0] -> NÃO FUNCIONA ASSIM PARA DATAFRAMES
# - vendas_df[:3] -> pega até a linha de índice 3 do dataframe
# - vendas_df[['coluna_x', 'coluna_y', 'coluna_z']] -> cria um novo dataframe com as colunas coluna_x, coluna_y e coluna_z
# - vendas_df['coluna_x'][0] -> pega o itemd a 1ª linha da coluna coluna_x

# %% [markdown]
# - Vamos ler um arquivo real, com a Base de Dados de Vendas da Empresa "Contoso"

# %%
import pandas as pd

vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')

#Exibindo uma coluna (parece um dicionário):
vendas_df['ID Cliente']
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
#Exibindo linhas (parece uma lista)
vendas_df[:3]
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1

# %% [markdown]
# ## Aplicação

# %% [markdown]
# - O 1º passo de toda Análise de Dados é você entender o que existe na sua base de dados
#
# Usaremos o .info() para isso

# %%
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 74.8+ MB

# %% [markdown]
# - Vamos criar então agora uma lista de Clientes

# %%
lista_clientes = vendas_df['ID Cliente']
lista_clientes
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %% [markdown]
# - Vamos criar agora uma lista com os produtos e as quantidades de vendas dele, caso a gente queira analisar só os produtos (independente de data ou de cliente)

# %%
produtos_quantidade = vendas_df[['ID Produto', 'Quantidade Vendida', 'Quantidade Devolvida']]
produtos_quantidade
# Out:
#         ID Produto  Quantidade Vendida  Quantidade Devolvida
# 0              981                   9                     1
# 1             1586                   9                     1
# 2             1444                  13                     1
# 3             1468                   6                     1
# 4             1106                   4                     1
# ...            ...                 ...                   ...
# 980637        2490                 120                     0
# 980638        2488                 120                     0
# 980639        2511                  80                     0
# 980640         436                  39                     0
# 980641        2510                  80                     0
#
# [980642 rows x 3 columns]

# %% [markdown]
# # Comparando, Tratando e Mesclando DataFrames
#
# ## Objetivo
#
# Vamos modificar os IDs para os nomes dos produtos, dos clientes e das lojas, para nossas análises ficarem mais intuitivas futuramente. Para isso, vamos criar um data frame com todos os detalhes.
#
# - Usaremos o método merge para isso e, depois se quisermos, podemos pegar apenas as colunas que queremos do dataframe final.

# %% [markdown]
# ### Criando nossos dataframes

# %%
import pandas as pd

# as vezes precisaremos mudar o encoding. Possiveis valores para testar:
# encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep = ';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep = ';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep = ';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep = ';')
#usaremos o display para ver todos os dataframes
display(vendas_df)
display(lojas_df)
display(produtos_df)
display(clientes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ### Vamos tirar as colunas inúteis do clientes_df ou pegar apenas as colunas que quisermos

# %% [markdown]
# .drop([coluna1, coluna2, coluna3]) -> retira as colunas: coluna1, coluna2, coluna3

# %%
# axis = 0: linha | axis = 1: colunas
clientes_df = clientes_df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis = 1)
display(clientes_df)
# Out:
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
# ...

# %%
# Pegando as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto','Nome do Produto']] 
lojas_df = lojas_df[['ID Loja','Nome da Loja']]
display(clientes_df)
display(produtos_df)
display(lojas_df)
# Out:
#        ID Cliente                         E-mail
# 0               1    glanfranchi0@mayoclinic.com
# 1               2      lroseblade1@bigcartel.com
# 2               3      gishchenko2@moonfruit.com
# 3               4    bjedrzejewsky3@e-recht24.de
# 4               5       sbredbury4@sitemeter.com
# ...           ...                            ...
# 39499       39500    brandy0@adventure-works.com
# 39500       39501   alicia12@adventure-works.com
# 39501       39502    connie4@adventure-works.com
# 39502       39503    shawn23@adventure-works.com
# 39503       39504  lindsey10@adventure-works.com
#
# [39504 rows x 2 columns]
#       ID Produto                                  Nome do Produto
# 0            873            Contoso Wireless Laser Mouse E50 Grey
# 1            879    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2            880   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3            881   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# ...

# %% [markdown]
# ### Agora vamos juntar os dataframes para ter 1 único dataframe com tudo "bonito"

# %% [markdown]
# novo_dataframe = dataframe1.merge(dataframe2, on='coluna')

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
display(vendas_df)
## juntando os dataframes
vendas_df = vendas_df.merge(produtos_df, on = 'ID Produto')
vendas_df = vendas_df.merge(lojas_df, on = 'ID Loja')
vendas_df = vendas_df.merge(clientes_df, on = 'ID Cliente')

## exibindo o dataframe final
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
#vamos renomear o e-mail para ficar claro que é do cliente
vendas_df = vendas_df.rename(columns = {'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ### Agora podemos começar as análises

# %% [markdown]
# # Resumos e um pouco de Visualização no pandas
#
#
# ## Resumo
#
# Vamos ver alguns métodos para analisar nossas tabelas (dataframes)
#
# Além disso, vamos usar os plot de gráfico padrões do pandas, mas no projeto de DataScience veremos outras mais bonitas e também muito práticas.
#
# OBS: O pandas usa o matplotlib (que vimos na seção de "módulos e bibliotecas") para plotar gráficos.<br>
# Se quiser personalizar mais do que o padrão do pandas, importe o matplotlib e use os métodos do matplotlib

# %% [markdown]
# - Preparando as bases de dados (o que fizemos na última aula)

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ### Qual cliente que comprou mais vezes?
#
# - Usaremos o método .value_counts() para contar quantas vezes cada valor do Dataframe aparece
# - Usaremos o método .plot() para exibir um gráfico

# %%
# Método .value_counts()
frequencia_clientes = vendas_df['E-mail do Cliente'].value_counts()
display(frequencia_clientes)
# Note que plotou a frequência que cada e-mail aparece na base de dados
# Out:
# karen33@adventure-works.com       77
# chloe77@adventure-works.com       74
# julia43@adventure-works.com       69
# destiny66@adventure-works.com     68
# gilbert9@adventure-works.com      68
#                                   ..
# isabella51@adventure-works.com     1
# wdalescoci@pbs.org                 1
# kbroggelliin@rakuten.co.jp         1
# connor15@adventure-works.com       1
# ekorneevmm@instagram.com           1
# Name: E-mail do Cliente, Length: 38907, dtype: int64

# %%
# Método .plot()
## Podemos plotar todos os clientes em um gráfico:
frequencia_clientes.plot()
# Out:
# <AxesSubplot:>

# %%
## Porém, temos 38907 clientes. Podemos escolher uma parcela de clientes que será plotado:
frequencia_clientes[:5].plot()
## Organizando o tamanho da figura com o figsize = (largura, altura):
frequencia_clientes[:5].plot(figsize = (15, 7))
## Podemos passar os valores que queremos utilizar no eixo y: yticks = sequência e o nome dos eixos (xlabel e ylabel)
frequencia_clientes[:5].plot(figsize = (15, 7), yticks = range(67, 78, 1), xlabel = 'E-mails dos Clientes', ylabel = 'Quantidade de Compras')
# Out:
# <AxesSubplot:xlabel='E-mails dos Clientes', ylabel='Quantidade de Compras'>

# %%
## Podemos mudar o tipo do gráfico usando kind = ''
frequencia_clientes[:5].plot(figsize = (15, 7), kind = 'pie')
# Out:
# <AxesSubplot:ylabel='E-mail do Cliente'>

# %% [markdown]
# ### Qual a Loja que mais vendeu?
#
# - Usaremos o .groupby para agrupar o nosso dataframe, de acordo com o que queremos (somando as quantidades de vendas, por exemplo)

# %%
vendas_lojas = vendas_df.groupby('Nome da Loja').sum()
display(vendas_lojas)
# Repare que ele aplica o groupby para todas as colunas e soma os valores de todas as linhas.
# Repare também que ele desconsidera as colunas que não apresentam dados "somáveis" (números)
# Out:
#                           Numero da Venda  ID Canal  ID Loja  ID Produto  \
# Nome da Loja
# Loja Contoso Albany            1202431493      5537   279756     2256167
# Loja Contoso Alexandria        1180450098      5336   449696     2254764
# Loja Contoso Amsterdam         1463641203      6295   721440     2855945
# Loja Contoso Anchorage         1214566953      5441   458964     2328863
# Loja Contoso Annapolis         1196644689      5401   466995     2243342
# ...                                   ...       ...      ...         ...
# Loja Contoso Yokohama          1277269788      5423   681377     2331010
# Loja Contoso York              1447746885      6402   600372     2736443
# Loja Contoso koln No.1         1473231489      6712   699944     2802822
# Loja Contoso koln No.2         1495673435      6758   699430     2846553
# Loja Contoso obamberg          1443837839      6544   709240     2756377
#
#                           ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
# Como queremos somente o Nome da Loja e a quantidade vendida. Faremos:
vendas_lojas = vendas_lojas[['Quantidade Vendida']]
display(vendas_lojas)
# Repare que não foi necessário passar a coluna "Nome da Loja" pois tal coluna passa a ser considerada
# a coluna de menor índice por conta do .groupby('Nome da Loja')
# Out:
#                           Quantidade Vendida
# Nome da Loja
# Loja Contoso Albany                    26353
# Loja Contoso Alexandria                26247
# Loja Contoso Amsterdam                 28294
# Loja Contoso Anchorage                 27451
# Loja Contoso Annapolis                 26065
# ...                                      ...
# Loja Contoso Yokohama                  28023
# Loja Contoso York                      27164
# Loja Contoso koln No.1                 29046
# Loja Contoso koln No.2                 29650
# Loja Contoso obamberg                  29336
#
# [306 rows x 1 columns]

# %% [markdown]
# - Agora precisamos pegar o maior valor. Temos 2 formas:
#     1. Ordenar o dataframe em ordem decrescente de Quantidade Vendida
#         - Método .sort_values
#     2. Pegar o Maior valor diretamente
#         - Métodos .max() e .idxmax()

# %%
# ordenando o dataframe
## https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
vendas_lojas = vendas_lojas.sort_values('Quantidade Vendida')
display(vendas_lojas)

## Se quisermos mudar a ordem: ascending = False
vendas_lojas = vendas_lojas.sort_values('Quantidade Vendida', ascending = False)
display(vendas_lojas)

## Podemos pegar até a quinta linha: vendas_lojas[:5]
#podemos plotar em um gráfico
vendas_lojas[:5].plot(figsize = (15, 7), kind = 'bar')
# Out:
#                                      Quantidade Vendida
# Nome da Loja
# Loja Contoso Venezia                                234
# Loja Contoso Racine No.2                            253
# Loja Contoso Marseille                              370
# Loja Contoso Paterson                               371
# Loja Contoso Berlin                                 379
# ...                                                 ...
# Loja Contoso North America Reseller              520176
# Loja Contoso Asia Online                         578458
# Loja Contoso Europe Online                       616845
# Loja Contoso North America Online                701961
# Loja Contoso Catalog                            1029117
#
# [306 rows x 1 columns]
#                                      Quantidade Vendida
# Nome da Loja
# Loja Contoso Catalog                            1029117
# Loja Contoso North America Online                701961
# Loja Contoso Europe Online                       616845
# ...

# %%
#pegando o maior valor e seu índice
maior_valor = vendas_lojas['Quantidade Vendida'].max()
melhor_loja = vendas_lojas['Quantidade Vendida'].idxmax()
print(melhor_loja, maior_valor)
# Out:
# Loja Contoso Catalog  1029117

# %% [markdown]
# ### Qual produto que menos vendeu?
#
# - Já temos uma lista criada para isso, basta verificarmos o final da lista (já que ela está ordenada) ou então usarmos os métodos:
#     1. min()
#     2. idxmin()

# %%
# Utilizando a ordenação da tabela (5 piores vendas):
vendas_lojas[-5:].plot(figsize = (15, 7), kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Nome da Loja'>

# %%
# usando min() e idxmin()
menor_valor = vendas_lojas['Quantidade Vendida'].min()
pior_loja =  vendas_lojas['Quantidade Vendida'].idxmin()
print(pior_loja, menor_valor)
# Out:
# Loja Contoso Venezia  234

# %% [markdown]
# # Filtrando informações nos dataframes
#
#
# ## Resumo
#
# Um dos grandes potenciais do pandas é para tratar condições.
#
# E a forma com que analisamos condições no dataframe é diferente do que já fizemos até agora no curso, vamos ver como funciona.

# %% [markdown]
# - Preparando as bases de dados

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df.head())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1           880458    23/11/2017    23/11/2017         0      306         235
# 2           191019    20/03/2017    21/03/2017         1      172         376
# 3            18610    08/01/2017    10/01/2017         2      200         448
# 4           287704    23/04/2017    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %% [markdown]
# ### Primeiro, vamos aplicar uma função normalmente. Qual o % das vendas que foi devolvido?
#
# - Para isso vamos somar as quantidades nas colunas correspondentes. Lembrando, o % vai ser: Total Devolvido / Total Vendido.

# %%
# Somando a quantidade vendida e a quantidade devolvida de cada loja, separadamente:
qtdd_vendida = vendas_df['Quantidade Vendida'].sum()
qtdd_devolvida = vendas_df['Quantidade Devolvida'].sum()
print('{:.2%}'.format(qtdd_devolvida/qtdd_vendida))
# Out:
# 1.17%

# %% [markdown]
# ### Agora, se quisermos fazer a mesma análise apenas para 1 loja. Queremos filtrar apenas os itens da Loja Contoso Europe Online e saber o % de devolução dessa loja.
#
# - Para isso, vamos precisar filtrar. A forma de filtrar nos dataframes é uma "simples" comparação

# %%
# Quero fazer um DF com a loja contoso europe online, selecionando o ID 306
vendas_loja_contoso_europe_online = vendas_df[vendas_df['ID Loja'] == 306]
display(vendas_loja_contoso_europe_online.head())

# Somando quantidade vendida e devolvida
vendas_contoso = vendas_loja_contoso_europe_online['Quantidade Vendida'].sum()
devolucoes_contoso = vendas_loja_contoso_europe_online['Quantidade Devolvida'].sum()
print('{:.2%}'.format(devolucoes_contoso/vendas_contoso))
# Out:
#     Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 1            880458    23/11/2017    23/11/2017         0      306
# 17           614980    18/08/2017    18/08/2017         0      306
# 18           786402    21/10/2017    25/10/2017         4      306
# 19           383897    25/05/2017    28/05/2017         3      306
# 77           559478    26/07/2017    29/07/2017         3      306
#
#     ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 1          235           10        6825                   8
# 17        1621            9       21344                   4
# 18         226           10       21344                   8
# 19         347            1       21344                  20
# 77        1382            1       24440                   5
#
#     Quantidade Devolvida                                    Nome do Produto  \
# 1                      0  Litware Home Theater System 7.1 Channel M710 B...
# ...

# %% [markdown]
# ### Vamos fazer em 2 passos para entender certinho o que está acontecendo.

# %%
#vendas_loja_contoso_europe_online = vendas_df[vendas_df['ID Loja'] == 306]
loja306 = vendas_df['ID Loja'] == 306
vendas_loja_contoso_europe_online = vendas_df[loja306]
display(vendas_loja_contoso_europe_online)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 1                880458    23/11/2017    23/11/2017         0      306
# 17               614980    18/08/2017    18/08/2017         0      306
# 18               786402    21/10/2017    25/10/2017         4      306
# 19               383897    25/05/2017    28/05/2017         3      306
# 77               559478    26/07/2017    29/07/2017         3      306
# ...                 ...           ...           ...       ...      ...
# 885329           865745    18/11/2017    24/11/2017         6      306
# 885356           907944    04/12/2017    04/12/2017         0      306
# 885386           919123    08/12/2017    08/12/2017         0      306
# 885390           964452    25/12/2017    25/12/2017         0      306
# 885415           900861    01/12/2017    05/12/2017         4      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ### Desafio: e se eu quisesse criar uma tabela apenas com as vendas da Loja Contoso Europe Online e que não tiveram nenhuma devolução. Quero criar essa tabela e saber quantas vendas são.
#
# - Repare que nesse caso são 2 condições, como fazemos isso?

# %%
#tudo junto (devemos usar os parêntesis para separar as condições)
loja306semdev_df = vendas_df[(vendas_df['ID Loja'] == 306) & (vendas_df['Quantidade Devolvida']) == 0]
display(loja306semdev_df.head())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1           880458    23/11/2017    23/11/2017         0      306         235
# 2           191019    20/03/2017    21/03/2017         1      172         376
# 3            18610    08/01/2017    10/01/2017         2      200         448
# 4           287704    23/04/2017    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %%
#separado
loja306 = vendas_df['ID Loja'] == 306
qtdd_devolvida_0 = vendas_df['Quantidade Devolvida'] == 0
loja306semdev_df2 = vendas_df[loja306 & qtdd_devolvida_0]
display(loja306semdev_df2.head())
# Out:
#     Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 1            880458    23/11/2017    23/11/2017         0      306
# 17           614980    18/08/2017    18/08/2017         0      306
# 18           786402    21/10/2017    25/10/2017         4      306
# 19           383897    25/05/2017    28/05/2017         3      306
# 77           559478    26/07/2017    29/07/2017         3      306
#
#     ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 1          235           10        6825                   8
# 17        1621            9       21344                   4
# 18         226           10       21344                   8
# 19         347            1       21344                  20
# 77        1382            1       24440                   5
#
#     Quantidade Devolvida                                    Nome do Produto  \
# 1                      0  Litware Home Theater System 7.1 Channel M710 B...
# ...

# %% [markdown]
# # Adicionando Colunas, Modificando Colunas e Valores

# %% [markdown]
# ### Vamos pegar o nosso dataframe novamente

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
# Perceba que as colunas de data têm o tipo "object". 
# Porém, para que possamos modificá-la, teremos que mudar o tipo dessas variáveis para 'datetime'
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980642 entries, 0 to 980641
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
#  10  Nome do Produto       980642 non-null  object
#  11  Nome da Loja          980642 non-null  object
#  12  E-mail do Cliente     980642 non-null  object
# dtypes: int64(8), object(5)
# memory usage: 104.7+ MB

# %% [markdown]
# ### Agora, e se quisermos acrescentar uma coluna com o mês, o dia e o ano de cada venda (e não só a data completa)

# %%
# Mudando para datetime
vendas_df['Data da Venda'] = pd.to_datetime(vendas_df['Data da Venda'], format = '%d/%m/%Y')
display(vendas_df)
vendas_df.info()
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    2017-01-01    02/01/2017         1       86
# 1                880458    2017-11-23    23/11/2017         0      306
# 2                191019    2017-03-20    21/03/2017         1      172
# 3                 18610    2017-01-08    10/01/2017         2      200
# 4                287704    2017-04-23    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    2017-11-23    23/11/2017         0      110
# 980638           920243    2017-12-09    10/12/2017         1      261
# 980639           467482    2017-06-21    25/06/2017         4      115
# 980640           853643    2017-11-13    20/11/2017         7      115
# 980641           903958    2017-12-02    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
# Agora podemos extrair os dados de dia, mês e ano. Vamos criar novas colunas:
## Podemos criar colunas somente colocando nomes que ainda não estão nas colunas
### .dt.year -> (formato do dado).(pegar o ano da coluna 'Data da Venda')
vendas_df['Ano da Venda'] = vendas_df['Data da Venda'].dt.year
vendas_df['Mês da Venda'] = vendas_df['Data da Venda'].dt.month
vendas_df['Dia da Venda'] = vendas_df['Data da Venda'].dt.day
display(vendas_df.head()) #.head pega os primeiros valores do DF
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    2017-01-01    02/01/2017         1       86         981
# 1           880458    2017-11-23    23/11/2017         0      306         235
# 2           191019    2017-03-20    21/03/2017         1      172         376
# 3            18610    2017-01-08    10/01/2017         2      200         448
# 4           287704    2017-04-23    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %% [markdown]
# ### E agora, caso a gente queira modificar 1 valor específico, como fazemos? Vamos importar novamente a base de produtos

# %%
novo_produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
display(novo_produtos_df.head())
#repare no .head() para pegar apenas os primeiros valores, é bem comum esse uso para ter uma visão do que são os dados
# Out:
#                                    Nome do Produto  \
# 0            Contoso Wireless Laser Mouse E50 Grey
# 1    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4  Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 3                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 4                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 1       Contoso  Econômico           6,63             13         879
# ...

# %% [markdown]
# ### Antes de entrar no próximo exemplo, precisamos falar de 2 métodos:
#     1. loc - permite pegar uma linha de acordo com o índice dela. Ele dá erro caso não encontre o índice. Isso é interessante principalmente quando o índice é uma informação relevante ao invés só do número do índice ou quando queremos pegar alguma linha específica do dataframe (ao invés de ir do início do dataframe até a linha 5, por exemplo).
#         Também podemos usar como loc[índice_linha, índice_coluna] para acessar um valor específico e modificá-lo.
#     2. iloc - enxerga o dataframe como linhas e colunas e consegue pegar o valor com um número de linha e um número de coluna. Repara que ele não analisa o valor do índice da linha e da coluna, apenas a posição importa.
#         Uso: iloc[num_linha, num_coluna]
#
# - Vendo na prática

# %%
# Podemos transformar uma coluna como índice: .set_index('coluna')
novo_produtos_df = novo_produtos_df.set_index('Nome do Produto')
display(novo_produtos_df.head())
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...

# %%
# O LOC PROCURA AS INFORMAÇÕES BASEADAS EM SEU ÍNDICE escrito: linha e coluna

# %%
#vamos pegar o preço produto Contoso Optical Wheel OEM PS/2 Mouse E60 Black
#por loc
novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey']
# Podemos pegar um valor de uma coluna desejada:
novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario']
# Out:
# '20,96'

# %%
#por iloc -  localiza pelo índice (número)
print(novo_produtos_df.iloc[0, 5])
# Out:
# 20,96

# %% [markdown]
# ### A empresa decidiu aumentar o preço do produto ID 873 (Contoso Wireless Laser Mouse E50 Grey) para 23 reais. Como fazemos, para modificar isso na nossa base?

# %%
novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario'] = 23
display(novo_produtos_df.head())
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...

# %%
## Voltando para o normal:
novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario'] = 20.96
# Segunda maneira
novo_produtos_df.loc[novo_produtos_df['ID Produto'] == 873, 'Preco Unitario'] = 23
display(novo_produtos_df.head())
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...

# %% [markdown]
# # Exportando do DataFrame para um csv
#
# ### Depois de modificar um DataFrame, ou até criar um, muitas vezes podemos exportar esse dataframe para um csv
#
# No pandas, isso é bem simples:
#
# dataframe.to_csv('nome_do_arquivo.csv', sep=',')

# %% [markdown]
# ### Lendo um DataFrame, modificando ele e exportando

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df.head())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1           880458    23/11/2017    23/11/2017         0      306         235
# 2           191019    20/03/2017    21/03/2017         1      172         376
# 3            18610    08/01/2017    10/01/2017         2      200         448
# 4           287704    23/04/2017    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %%
# agora vamos criar o csv - ele é salvo no local onde está o arquivo desse programa
vendas_df.to_csv('Novo Vendas 2017.csv', sep = ';')
# caso quisermos criar em um novo local, basta colocar o endereço

# %% [markdown]
# ### Criando um dicionário, transformando o dicionário em um DataFrame e Exportando para csv

# %%
vendas_produtos = {'iphone': [558147, 951642], 'galaxy': [712350, 244295], 'ipad': [573823, 26964], 'tv': [405252, 787604], 'máquina de café': [718654, 867660], 'kindle': [531580, 78830], 'geladeira': [973139, 710331], 'adega': [892292, 646016], 'notebook dell': [422760, 694913], 'notebook hp': [154753, 539704], 'notebook asus': [887061, 324831], 'microsoft surface': [438508, 667179], 'webcam': [237467, 295633], 'caixa de som': [489705, 725316], 'microfone': [328311, 644622], 'câmera canon': [591120, 994303]}
vendas_produtos_df = pd.DataFrame.from_dict(vendas_produtos)
display(vendas_produtos_df)
# Out:
#    iphone  galaxy    ipad      tv  máquina de café  kindle  geladeira   adega  \
# 0  558147  712350  573823  405252           718654  531580     973139  892292
# 1  951642  244295   26964  787604           867660   78830     710331  646016
#
#    notebook dell  notebook hp  notebook asus  microsoft surface  webcam  \
# 0         422760       154753         887061             438508  237467
# 1         694913       539704         324831             667179  295633
#
#    caixa de som  microfone  câmera canon
# 0        489705     328311        591120
# 1        725316     644622        994303

# %%
# Se quisermos mudar:
vendas_produtos_df = pd.DataFrame.from_dict(vendas_produtos, orient = 'index')
display(vendas_produtos_df)
# Out:
#                         0       1
# iphone             558147  951642
# galaxy             712350  244295
# ipad               573823   26964
# tv                 405252  787604
# máquina de café    718654  867660
# kindle             531580   78830
# geladeira          973139  710331
# adega              892292  646016
# notebook dell      422760  694913
# notebook hp        154753  539704
# notebook asus      887061  324831
# microsoft surface  438508  667179
# webcam             237467  295633
# caixa de som       489705  725316
# microfone          328311  644622
# câmera canon       591120  994303

# %%
# Dando nome às colunas:
vendas_produtos_df = vendas_produtos_df.rename(columns = {0: 'Vendas 2019', 1: 'Vendas 2020'})
display(vendas_produtos_df)
# Out:
#                    Vendas 2019  Vendas 2020
# iphone                  558147       951642
# galaxy                  712350       244295
# ipad                    573823        26964
# tv                      405252       787604
# máquina de café         718654       867660
# kindle                  531580        78830
# geladeira               973139       710331
# adega                   892292       646016
# notebook dell           422760       694913
# notebook hp             154753       539704
# notebook asus           887061       324831
# microsoft surface       438508       667179
# webcam                  237467       295633
# caixa de som            489705       725316
# microfone               328311       644622
# câmera canon            591120       994303

# %%
# Exportando CSV:
vendas_produtos_df.to_csv('Novo Vendas Produtos.csv', sep = ';', encoding = 'latin1' )

# %% [markdown]
# # pandas lendo csv da internet
#
# ### Essa é uma das formas de importar arquivos da internet, direto do pandas. Mas nem sempre você vai conseguir abrir assim direto.
#
# ### 2 situações principais em que você consegue fazer direto
#
# 1. Arquivo csv direto no link (melhor dos mundos)
# 2. O arquivo csv é gerado para você, mas fica no meio de uma requisição que precisa ser tratada.

# %% [markdown]
# ### Caso 1: csv direto no link
#
# - Criei um arquivo csv e disponibilizei o link para download no Drive: https://drive.google.com/uc?authuser=0&id=1UzlPy6CZQeAzDXhfc_2sHEyK_Jb50vJs&export=download

# %%
import pandas as pd
url = 'https://drive.google.com/uc?authuser=0&id=1UzlPy6CZQeAzDXhfc_2sHEyK_Jb50vJs&export=download'
cotacao_df = pd.read_csv(url)
display(cotacao_df)
# Out:
#               Date   Price    Open    High     Low Change %
# 0     Jan 01, 2020  4.0195  4.0195  4.0195  4.0195    0.00%
# 1     Dec 31, 2019  4.0195  4.0201  4.0201  4.0195    0.00%
# 2     Dec 30, 2019  4.0195  4.0484  4.0484  4.0084   -0.65%
# 3     Dec 27, 2019  4.0460  4.0568  4.0614  4.0339   -0.25%
# 4     Dec 26, 2019  4.0560  4.0827  4.0827  4.0453   -0.68%
# ...            ...     ...     ...     ...     ...      ...
# 3908  Jan 07, 2005  2.7120  2.7230  2.7290  2.6890   -0.36%
# 3909  Jan 06, 2005  2.7218  2.7140  2.7340  2.7060    0.27%
# 3910  Jan 05, 2005  2.7145  2.6980  2.7331  2.6910   -0.17%
# 3911  Jan 04, 2005  2.7190  2.6720  2.7230  2.6720    1.61%
# 3912  Jan 03, 2005  2.6759  2.6610  2.6760  2.6520    0.75%
#
# [3913 rows x 6 columns]

# %% [markdown]
# ### Caso 2: csv em uma requisição que precisa ser tratada
#
# Pesquisei por histórico de preços do café no Google e cheguei nesse site: http://portalweb.cooxupe.com.br:8080/portal/precohistoricocafe_2.jsp

# %%
import pandas as pd
import io
import requests #puxa o conteúdo de um link

url = 'http://portalweb.cooxupe.com.br:8080/portal/precohistoricocafe_2.jsp?d-3496238-e=2&6578706f7274=1'
conteudo_url = requests.get(url).content # Pega o link
arquivo = io.StringIO(conteudo_url.decode('latin1')) # lendo a string
cafe_df = pd.read_csv(arquivo, sep = r'\t', engine = 'python')
display(cafe_df.head())
# Out:
#     "Ano" "Janeiro" "Fevereiro"   "Março"   "Abril"    "Maio"   "Junho"  \
# 0  "2021"  "639.23"    "695.33"  "726.88"  "744.05"  "811.06"  "793.67"
# 1  "2020"  "501.68"    "493.67"  "555.23"  "576.55"  "566.69"  "518.24"
# 2  "2019"  "399.98"    "398.08"  "390.17"     "381"  "392.92"  "427.09"
# 3  "2018"  "432.26"    "430.47"  "421.87"   "431.5"  "446.76"  "466.24"
# 4  "2017"  "514.21"     "505.3"  "488.99"  "479.25"  "471.89"  "473.76"
#
#     "Julho"  "Agosto" "Setembro" "Outubro" "Novembro" "Dezembro"
# 0  "762.36"  "772.03"   "851.11"        ""         ""         ""
# 1  "531.82"  "555.65"    "545.8"  "521.32"   "551.45"   "586.98"
# 2  "442.84"  "417.23"   "415.82"  "406.17"   "447.67"   "518.57"
# 3  "474.96"  "459.73"   "442.37"  "424.54"    "429.7"   "410.42"
# 4  "508.55"  "511.44"   "477.19"  "437.82"   "450.84"   "449.44"

# %% [markdown]
# ### Apenas para lembrar os tipos de encoding principais que vamos usar:
#
# - encoding='latin1'
# - encoding='ISO-8859-1'
# - encoding='utf-8'
# - encoding='cp1252'

# %% [markdown]
# # Integração Python + Excel
#
# ### 2 formas:
#
# 1. Pandas
#     - Mais usada no geral
#     - Trata o Excel como uma base de dados
#     - Faz o que quiser com o arquivo
#     - Pode desfazer a estrutura original do arquivo, caso queira editar
#
# 2. Openpyxl
#     - Trata o Excel como uma planilha mesmo que pode ter várias coisas
#     - Edita "como se fosse um VBA"
#     - Menos eficiente
#     - Mantém mais a estrutura original do arquivo, mas cuidado porque não necessariamente tudo, então tem que testar

# %% [markdown]
# ### Desafio
#
# - Temos uma planilha de produtos e serviços. Com o aumento de imposto sobre os serviços, temos que atualizar o preço dos produtos impactados pela mudança.
#
# Novo Multiplicador Imposto: 1.5

# %% [markdown]
# #### Usando PANDAS

# %%
import pandas as pd
tabela = pd.read_excel('Produtos.xlsx')
display(tabela)
# Out:
#          Produtos  Preço Base Original     Tipo  Multiplicador Imposto  \
# 0          Tablet               999.99  Produto                    1.1
# 1   Pós Graduação              4500.00  Serviço                    1.3
# 2         Celular               899.99  Produto                    1.1
# 3  Passagem Aérea               799.00  Serviço                    1.3
# 4      Computador              3000.00  Produto                    1.1
# 5             SPA               480.48  Serviço                    1.3
# 6    Corte Cabelo                50.00  Serviço                    1.3
#
#    Preço Base Reais
# 0          1099.989
# 1          5850.000
# 2           989.989
# 3          1038.700
# 4          3300.000
# 5           624.624
# 6            65.000

# %%
# Atualizando o multiplicador
tabela.loc[tabela['Tipo'] == 'Serviço', 'Multiplicador Imposto'] = 1.5
display(tabela)
# Out:
#          Produtos  Preço Base Original     Tipo  Multiplicador Imposto  \
# 0          Tablet               999.99  Produto                    1.1
# 1   Pós Graduação              4500.00  Serviço                    1.5
# 2         Celular               899.99  Produto                    1.1
# 3  Passagem Aérea               799.00  Serviço                    1.5
# 4      Computador              3000.00  Produto                    1.1
# 5             SPA               480.48  Serviço                    1.5
# 6    Corte Cabelo                50.00  Serviço                    1.5
#
#    Preço Base Reais
# 0          1099.989
# 1          5850.000
# 2           989.989
# 3          1038.700
# 4          3300.000
# 5           624.624
# 6            65.000

# %%
# Fazendo a multiplicação "Preço Base Original" * "Multiplicador Imposto"
tabela['Preço Base Reais'] = tabela['Preço Base Original'] * tabela['Multiplicador Imposto']
display(tabela)
# Out:
#          Produtos  Preço Base Original     Tipo  Multiplicador Imposto  \
# 0          Tablet               999.99  Produto                    1.1
# 1   Pós Graduação              4500.00  Serviço                    1.5
# 2         Celular               899.99  Produto                    1.1
# 3  Passagem Aérea               799.00  Serviço                    1.5
# 4      Computador              3000.00  Produto                    1.1
# 5             SPA               480.48  Serviço                    1.5
# 6    Corte Cabelo                50.00  Serviço                    1.5
#
#    Preço Base Reais
# 0          1099.989
# 1          6750.000
# 2           989.989
# 3          1198.500
# 4          3300.000
# 5           720.720
# 6            75.000

# %%
# Importando excel (Index = False - sem a coluna de índice)
tabela.to_excel('Produtos Pandas.xlsx', index = False)

# %% [markdown]
# #### Usando openpyxl

# %%
from openpyxl import Workbook, load_workbook
# importando a planilha
planilha = load_workbook('Produtos.xlsx')
# pegando a aba ativa
aba_ativa = planilha.active

for celula in aba_ativa['C']: # aba_ativa é uma lista de células
    if celula.value == 'Serviço':
        linha = celula.row # Pegando a mesma linha que a célula escrita serviço
        aba_ativa[f'D{linha}'] = 1.5 # f - string que pode ser formatada com variáveis
        
planilha.save("ProdutosOpenPy.xlsx")

# %% [markdown]
# # E quando o nosso código demora muito? Será que travou? Quanto tempo vai demorar?
#
# ### Biblioteca/Módulo tqdm
#
# - Vamos importar os arquivos csv da Empresa Contoso e tratar como fizemos ao longo desse módulo

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df.head())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1           880458    23/11/2017    23/11/2017         0      306         235
# 2           191019    20/03/2017    21/03/2017         1      172         376
# 3            18610    08/01/2017    10/01/2017         2      200         448
# 4           287704    23/04/2017    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %% [markdown]
# ### Agora, imagina que a Loja Contoso Roma (ID 222), para tentar burlar o sistema de metas, diminuiu 1 da quantidade devolvida de todas as vendas que ela teve. Descobrindo isso, precisamos ajeitar a base
#
# - Farei com um for, principalmente por motivos didáticos, mas teríamos outras formas de fazer isso também.

# %%
from tqdm import tqdm

pbar = tqdm(total = len(vendas_df['ID Loja']), position = 0, leave = True)

for i, id_loja in enumerate(vendas_df['ID Loja']):
    pbar.update()
    if id_loja == 222:
        vendas_df.loc[i, ['Quantidade Devolvida']] += 1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/864652407.py in <module>
# ----> 1 from tqdm import tqdm
#       2
#       3 pbar = tqdm(total = len(vendas_df['ID Loja']), position = 0, leave = True)
#       4
#       5 for i, id_loja in enumerate(vendas_df['ID Loja']):
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
display(vendas_df.head())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1           880458    23/11/2017    23/11/2017         0      306         235
# 2           191019    20/03/2017    21/03/2017         1      172         376
# 3            18610    08/01/2017    10/01/2017         2      200         448
# 4           287704    23/04/2017    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %% [markdown]
# # Exercício - Mini Projeto de Análise de Dados
#
# Vamos fazer um exercício completo de pandas para um miniprojeto de análise de dados.
#
# Esse exercício vai obrigar a gente a usar boa parte dos conhecimento de pandas e até de outros módulos que já aprendemos ao longo do curso.
#
# ### O que temos?
#
# Temos os dados de 2019 de uma empresa de prestação de serviços.
#
# - CadastroFuncionarios
# - CadastroClientes
# - BaseServiçosPrestados
#
# Obs1: Para ler arquivos csv, temos o read_csv<br>
# Obs2: Para ler arquivos xlsx (arquivos em excel normais, que não são padrão csv), temos o read_excel
#
# ### O que queremos saber/fazer?
#
# 1. Valor Total da Folha Salarial -> Qual foi o gasto total com salários de funcionários pela empresa? <br>
#     Sugestão: calcule o salário total de cada funcionário, salário + benefícios + impostos, depois some todos os salários
#
#
# 2. Qual foi o faturamento da empresa?<br>
#     Sugestão: calcule o faturamento total de cada serviço e depois some o faturamento de todos
#
#
# 3. Qual o % de funcionários que já fechou algum contrato?<br>
#     Sugestão: na base de serviços temos o funcionário que fechou cada serviço. Mas nem todos os funcionários que a empresa tem já fecharam algum serviço.<br>
#     . Na base de funcionários temos uma lista com todos os funcionários<br>
#     . Queremos calcular Qtde_Funcionarios_Fecharam_Serviço / Qtde_Funcionários_Totais<br>
#     . Para calcular a qtde de funcionários que fecharam algum serviço, use a base de serviços e conte quantos funcionários tem ali. Mas lembre-se, cada funcionário só pode ser contado uma única vez.<br><br>
#     Dica: se você aplicar o método .unique() em uma variável que é apenas 1 coluna de um dataframe, ele vai excluir todos os valores duplicados daquela coluna.<br>
#     Ex: unicos_colunaA = dataframe['colunaA'].unique() te dá como resposta uma lista com todos os itens da colunaA aparecendo uma única vez. Todos os valores repetidos da colunaA são excluidos da variável unicos_colunaA
#
#
# 4. Calcule o total de contratos que cada área da empresa já fechou
#
#
# 5. Calcule o total de funcionários por área
#
#
# 6. Qual o ticket médio mensal (faturamento médio mensal) dos contratos?<br>
#     Dica: .mean() calcula a média -> exemplo: media_colunaA = dataframe['colunaA'].mean()
#
# Obs: Lembrando as opções mais usuais de encoding:<br>
# encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'
#
# Observação Importante: Se o seu código der um erro na hora de importar os arquivos:<br>
# - CadastroClientes.csv
# - CadastroFuncionarios.csv
#
# Use separador ";" (ponto e vírgula) para resolver

# %%
import pandas as pd
cadastro_funcionarios_df = pd.read_csv('CadastroFuncionarios.csv', sep = ';', decimal = ',')
cadastro_clientes_df = pd.read_csv('CadastroClientes.csv', sep = ';')
base_servicos_df = pd.read_csv('BaseServiçosPrestados.csv', sep = ';', encoding = 'latin1')

# Tirando os "Unnamed"s (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html?highlight=dropna#pandas.DataFrame.dropna)
base_servicos_df = base_servicos_df.dropna(axis = 1) # axis = 0 -> linha | axis = 1 -> coluna

# Excluindo as colunas: estado civil e cargo:
cadastro_funcionarios_df = cadastro_funcionarios_df.drop(['Estado Civil', 'Cargo'], axis = 1)

display(cadastro_funcionarios_df.head())
display(cadastro_clientes_df.head())
display(base_servicos_df.head())
# Out:
#    ID Funcionário           Nome Completo  Salario Base  Impostos  Beneficios  \
# 0               1        Gabriel Mesquita         21910   10955.0      4382.0
# 1               2             João Haddad          5404    2702.0      1080.8
# 2               3  Amanda Marques Ribeiro         16066    8033.0      3213.2
# 3               4         Guilherme Nunez         21305   10652.5      4261.0
# 4               5           Adelino Gomes          5098    2549.0      1019.6
#
#     VT      VR            Area
# 0  242  719.04       Operações
# 1  154  574.56       Logística
# 2  154  729.12  Administrativo
# 3  220  524.16  Administrativo
# 4  176  725.76  Administrativo
#    ID Cliente             Cliente  Valor Contrato Mensal
# 0           1  Teixeira Gonçalves                    540
# 1           2        Souza Santos                   1260
# 2           3        Emídio Alves                   3195
# 3           4        Santos Costa                   2520
# ...

# %% [markdown]
# ## 1. Valor Total da Folha Salarial

# %%
# Calculando salário total de cada funcionário
## Adicionando uma nova coluna com o salário total (Salário Total = Salario Base + Impostos + Benefícios)
cadastro_funcionarios_df['Salario Total'] = cadastro_funcionarios_df['Salario Base'] + cadastro_funcionarios_df['Impostos'] + cadastro_funcionarios_df['Beneficios']+cadastro_funcionarios_df['VT']+cadastro_funcionarios_df['VR']

# Somando o salário total e printando
print('O valor total da folha salarial foi de: R${:,}'.format(cadastro_funcionarios_df['Salario Total'].sum()))
# Out:
# O valor total da folha salarial foi de: R$2,717,493.22

# %% [markdown]
# ## 2. Faturamento da Empresa
# - Sugestão: calcule o faturamento total de cada serviço e depois some o faturamento de todos

# %%
# Mesclando os dataframes de interesse: (base_servicos_df + cadastro_clientes_df)
faturamento_df = base_servicos_df.merge(cadastro_clientes_df, on = 'ID Cliente')
display(faturamento_df)

# Podemos escolher quais colunas queremos juntar:
faturamento2_df = base_servicos_df[['ID Cliente', 'Tempo Total de Contrato (Meses)']].merge(cadastro_clientes_df[['ID Cliente', 'Valor Contrato Mensal']], on = 'ID Cliente')
display(faturamento2_df)
# Out:
#     Codigo do Servico  ID Funcionário  ID Cliente  \
# 0              OS0001              67           1
# 1              OS0002              17           2
# 2              OS0003             116           4
# 3              OS0004              37           5
# 4              OS0005             130           6
# ..                ...             ...         ...
# 232            OS0233             111         315
# 233            OS0234             124         316
# 234            OS0235              72         317
# 235            OS0236              90         319
# 236            OS0237              22         320
#
#      Tempo Total de Contrato (Meses)             Cliente  \
# 0                                 14  Teixeira Gonçalves
# 1                                 12        Souza Santos
# 2                                 14        Santos Costa
# 3                                  8         Do Monteiro
# 4                                  8         Soares Lobo
# ...

# %%
# Multiplicando tempo total de contrato pelo valor do contrato e atribuindo em nova coluna
faturamento_df['Valor Total'] = faturamento_df['Tempo Total de Contrato (Meses)'] * faturamento_df['Valor Contrato Mensal']
display(faturamento_df.head())
# Out:
#   Codigo do Servico  ID Funcionário  ID Cliente  \
# 0            OS0001              67           1
# 1            OS0002              17           2
# 2            OS0003             116           4
# 3            OS0004              37           5
# 4            OS0005             130           6
#
#    Tempo Total de Contrato (Meses)             Cliente  Valor Contrato Mensal  \
# 0                               14  Teixeira Gonçalves                    540
# 1                               12        Souza Santos                   1260
# 2                               14        Santos Costa                   2520
# 3                                8         Do Monteiro                   3510
# 4                                8         Soares Lobo                   2340
#
#    Valor Total
# 0         7560
# 1        15120
# 2        35280
# 3        28080
# 4        18720

# %%
# Somando o valor de todos os serviços:
faturamento_total = faturamento_df['Valor Total'].sum()
print('O faturamento da empresa foi de: R${:,}'.format(faturamento_total))
# Out:
# O faturamento da empresa foi de: R$5,519,160

# %% [markdown]
# ## 3.% de funcionários que fecharam contrato
# - Sugestão: na base de serviços temos o funcionário que fechou cada serviço. Mas nem todos os funcionários que a empresa tem já fecharam algum serviço.
#     - Na base de funcionários temos uma lista com todos os funcionários
#     - Queremos calcular Qtde_Funcionarios_Fecharam_Serviço / Qtde_Funcionários_Totais
#     - Para calcular a qtde de funcionários que fecharam algum serviço, use a base de serviços e conte quantos funcionários tem ali. Mas lembre-se, cada funcionário só pode ser contado uma única vez.
#     - Dica: se você aplicar o método .unique() em uma variável que é apenas 1 coluna de um dataframe, ele vai excluir todos os valores duplicados daquela coluna.
#         - Ex: unicos_colunaA = dataframe['colunaA'].unique() te dá como resposta uma lista com todos os itens da colunaA aparecendo uma única vez. Todos os valores repetidos da colunaA são excluidos da variável unicos_colunaA

# %%
# Funcionários totais
qtdd_funcionarios_totais = len(cadastro_funcionarios_df['ID Funcionário'])

# Funcionários que fecharam serviços
qtdd_funcionarios_fecharam_servico = len(base_servicos_df['ID Funcionário'].unique())

print('Percentual de funcionários que fecharam contrato: {:.2%}'.format(qtdd_funcionarios_fecharam_servico/qtdd_funcionarios_totais))
# Out:
# Percentual de funcionários que fecharam contrato: 86.84%

# %% [markdown]
# ## 4. Total de contratos que cada área da empresa já fechou

# %%
# merge:
aux_df = cadastro_funcionarios_df[['ID Funcionário', 'Area']].merge(faturamento_df[['ID Funcionário', 'Tempo Total de Contrato (Meses)', 'Valor Total']], on = 'ID Funcionário')

# Contando:
contratos_por_area = aux_df['Area'].value_counts()

display(contratos_por_area)
contratos_por_area.plot(figsize = (15, 6), kind = 'bar')
# Out:
# Administrativo    63
# Operações         48
# Comercial         44
# Financeiro        42
# Logística         40
# Name: Area, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ## 5. Total de funcionários por área

# %%
qtdd_funcionarios_area = cadastro_funcionarios_df['Area'].value_counts()
display(qtdd_funcionarios_area)
qtdd_funcionarios_area.plot(figsize = (15, 6), kind = 'bar')
# Out:
# Administrativo    26
# Comercial         26
# Operações         23
# Logística         21
# Financeiro        18
# Name: Area, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ## 6. Ticket médio mensal dos contratos
# - Dica: .mean() calcula a média -> exemplo: media_colunaA = dataframe['colunaA'].mean()

# %%
ticket_medio_mensal = cadastro_clientes_df['Valor Contrato Mensal'].mean()
print(ticket_medio_mensal)
# Out:
# 2502.5625
